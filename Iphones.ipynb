# %% [markdown]
# # Scraping iPhones Data
#
# ## Description
# The objective of this project is to scrape iPhones data from wikipedia and exporting to csv file.

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Scraping data

# %%
url = 'https://en.wikipedia.org/wiki/IPhone'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# To Preview html in another file
with open('soup.txt','w') as f:
    f.write(str(soup))

# %% [markdown]
# ### Finding our target table

# %%
table = soup.find('table', attrs={'class' : "wikitable", 'style':'font-size:88%; margin-left:auto; margin-right:auto; width:99%'})
body = table.find('tbody')

# %% [markdown]
# ### Building our data frame

# %%
models = []
os = []
price = []
rows = body.find_all('tr')
for row in rows:
    models.append(row.find('th').text.strip())
    try:
        os.append(row.find_all('td')[0].text.strip())
    except:
        os.append(np.nan)
    try:
        price.append(row.find_all('td')[-1].text.strip())
    except:
        price.append(np.nan)

# %%
df = pd.DataFrame(data={'model':models, 'os':os, 'price':price})
df
# Out:
#                          model  \
# 0                        model
# 1                      with OS
# 2                          max
# 3                       iPhone
# 4                    iPhone 3G
# 5                   iPhone 3GS
# 6                     iPhone 4
# 7                    iPhone 4S
# 8                     iPhone 5
# 9                    iPhone 5C
# 10                   iPhone 5S
# 11           iPhone 6 / 6 Plus
# 12         iPhone 6S / 6S Plus
# 13             iPhone SE (1st)
# 14           iPhone 7 / 7 Plus
# 15           iPhone 8 / 8 Plus
# 16                    iPhone X
# 17                   iPhone XR
# 18          iPhone XS / XS Max
# 19                   iPhone 11
# 20  iPhone 11 Pro / 11 Pro Max
# 21             iPhone SE (2nd)
# 22         iPhone 12 / 12 Mini
# 23  iPhone 12 Pro / 12 Pro Max
# 24         iPhone 13 / 13 Mini
# 25  iPhone 13 Pro / 13 Pro Max
# 26                     Legend:
# 27                     Legend:
#
#                                                    os  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                       iPhone OS 1.0
# 4                                       iPhone OS 2.0
# 5                                       iPhone OS 3.0
# 6                                             iOS 4.0
# 7                                             iOS 5.0
# 8                                             iOS 6.0
# 9                                             iOS 7.0
# 10                                            iOS 7.0
# 11                                            iOS 8.0
# 12                                          iOS 9.0.1
# 13                                            iOS 9.3
# 14                                         iOS 10.0.1
# 15                                           iOS 11.0
# 16                                         iOS 11.0.1
# 17                                           iOS 12.0
# 18                                           iOS 12.0
# 19                                           iOS 13.0
# 20                                           iOS 13.0
# 21                                           iOS 13.4
# 22                  iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 23           iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 24                                           iOS 15.0
# 25                                           iOS 15.0
# 26  Legend:\n\n  Discontinued and unsupported\n\n ...
# 27                       Discontinued and unsupported
#
#                                                 price
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                          $499/$599*
# 4                                 $199/$299*$599/$699
# 5                                              1 year
# 6                                           iOS 7.1.2
# 7                       $199/$299/$399*$649/$749/$849
# 8                                             4 years
# 9                                  $99/$199*$549/$649
# 10                      $199/$299/$399*$649/$749/$849
# 11  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 12  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 13                                          $399/$499
# 14  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 15                            $699/$849Plus:$799/$949
# 16                               $549/$699*$999/$1149
# 17                                     $749/$799/$899
# 18              $999/$1149/$1349Max:$1099/$1249/$1449
# 19                                     $699/$749/$849
# 20             $999/$1149/$1349Max: $1099/$1249/$1449
# 21                                     $399/$449/$549
# 22           $829/$879/$979**\nMini: $729/$779/$879**
# 23           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 24         $829/$929/$1129**\nMini: $729/$829/$1029**
# 25  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...
# 26              **$30 off with carrier special offers
# 27              **$30 off with carrier special offers

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Selecting only iPhones' rows

# %%
df = df.iloc[3:26]
df = df.reset_index(drop=True)
df.tail()
# Out:
#                          model                                        os  \
# 18             iPhone SE (2nd)                                  iOS 13.4
# 19         iPhone 12 / 12 Mini         iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 20  iPhone 12 Pro / 12 Pro Max  iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 21         iPhone 13 / 13 Mini                                  iOS 15.0
# 22  iPhone 13 Pro / 13 Pro Max                                  iOS 15.0
#
#                                                 price
# 18                                     $399/$449/$549
# 19           $829/$879/$979**\nMini: $729/$779/$879**
# 20           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 21         $829/$929/$1129**\nMini: $729/$829/$1029**
# 22  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...

# %% [markdown]
# ### Manually adding prices

# %%
df.at[2, 'price'] = '$199'
df.at[3, 'price'] = '$599'
df.at[5, 'price'] = '$649'

# %% [markdown]
# ### Separate models of the same generation to separate rows

# %%
new_models = []
old_models = df.model

for model in old_models:
    new_models.append(model.split('/'))
df.model = new_models

df = df.explode('model').reset_index(drop=True)
df
# Out:
#               model                                        os  \
# 0            iPhone                             iPhone OS 1.0
# 1         iPhone 3G                             iPhone OS 2.0
# 2        iPhone 3GS                             iPhone OS 3.0
# 3          iPhone 4                                   iOS 4.0
# 4         iPhone 4S                                   iOS 5.0
# 5          iPhone 5                                   iOS 6.0
# 6         iPhone 5C                                   iOS 7.0
# 7         iPhone 5S                                   iOS 7.0
# 8         iPhone 6                                    iOS 8.0
# 9            6 Plus                                   iOS 8.0
# 10       iPhone 6S                                  iOS 9.0.1
# 11          6S Plus                                 iOS 9.0.1
# 12  iPhone SE (1st)                                   iOS 9.3
# 13        iPhone 7                                 iOS 10.0.1
# 14           7 Plus                                iOS 10.0.1
# 15        iPhone 8                                   iOS 11.0
# 16           8 Plus                                  iOS 11.0
# 17         iPhone X                                iOS 11.0.1
# 18        iPhone XR                                  iOS 12.0
# 19       iPhone XS                                   iOS 12.0
# 20           XS Max                                  iOS 12.0
# 21        iPhone 11                                  iOS 13.0
# 22   iPhone 11 Pro                                   iOS 13.0
# 23       11 Pro Max                                  iOS 13.0
# 24  iPhone SE (2nd)                                  iOS 13.4
# 25       iPhone 12          iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 26          12 Mini         iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 27   iPhone 12 Pro   iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 28       12 Pro Max  iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 29       iPhone 13                                   iOS 15.0
# 30          13 Mini                                  iOS 15.0
# 31   iPhone 13 Pro                                   iOS 15.0
# 32       13 Pro Max                                  iOS 15.0
#
#                                                 price
# 0                                          $499/$599*
# 1                                 $199/$299*$599/$699
# 2                                                $199
# 3                                                $599
# 4                       $199/$299/$399*$649/$749/$849
# 5                                                $649
# 6                                  $99/$199*$549/$649
# 7                       $199/$299/$399*$649/$749/$849
# 8   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 9   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 10  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 11  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 12                                          $399/$499
# 13  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 14  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 15                            $699/$849Plus:$799/$949
# 16                            $699/$849Plus:$799/$949
# 17                               $549/$699*$999/$1149
# 18                                     $749/$799/$899
# 19              $999/$1149/$1349Max:$1099/$1249/$1449
# 20              $999/$1149/$1349Max:$1099/$1249/$1449
# 21                                     $699/$749/$849
# 22             $999/$1149/$1349Max: $1099/$1249/$1449
# 23             $999/$1149/$1349Max: $1099/$1249/$1449
# 24                                     $399/$449/$549
# 25           $829/$879/$979**\nMini: $729/$779/$879**
# 26           $829/$879/$979**\nMini: $729/$779/$879**
# 27           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 28           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 29         $829/$929/$1129**\nMini: $729/$829/$1029**
# 30         $829/$929/$1129**\nMini: $729/$829/$1029**
# 31  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...
# 32  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...

# %% [markdown]
# ### Adding "iPhone" to the splitted rows

# %%
new_models = []
for model in df.model:
    if model.startswith('iPhone'):
        new_models.append(model)
    else:
        new_models.append(f'iPhone {model.strip()}')
df.model = new_models
df
# Out:
#                 model                                        os  \
# 0              iPhone                             iPhone OS 1.0
# 1           iPhone 3G                             iPhone OS 2.0
# 2          iPhone 3GS                             iPhone OS 3.0
# 3            iPhone 4                                   iOS 4.0
# 4           iPhone 4S                                   iOS 5.0
# 5            iPhone 5                                   iOS 6.0
# 6           iPhone 5C                                   iOS 7.0
# 7           iPhone 5S                                   iOS 7.0
# 8           iPhone 6                                    iOS 8.0
# 9       iPhone 6 Plus                                   iOS 8.0
# 10         iPhone 6S                                  iOS 9.0.1
# 11     iPhone 6S Plus                                 iOS 9.0.1
# 12    iPhone SE (1st)                                   iOS 9.3
# 13          iPhone 7                                 iOS 10.0.1
# 14      iPhone 7 Plus                                iOS 10.0.1
# 15          iPhone 8                                   iOS 11.0
# 16      iPhone 8 Plus                                  iOS 11.0
# 17           iPhone X                                iOS 11.0.1
# 18          iPhone XR                                  iOS 12.0
# 19         iPhone XS                                   iOS 12.0
# 20      iPhone XS Max                                  iOS 12.0
# 21          iPhone 11                                  iOS 13.0
# 22     iPhone 11 Pro                                   iOS 13.0
# 23  iPhone 11 Pro Max                                  iOS 13.0
# 24    iPhone SE (2nd)                                  iOS 13.4
# 25         iPhone 12          iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 26     iPhone 12 Mini         iOS 14.1 (12)\niOS 14.2 (12 Mini)
# 27     iPhone 12 Pro   iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 28  iPhone 12 Pro Max  iOS 14.1 (12 Pro)\niOS 14.2 (12 Pro Max)
# 29         iPhone 13                                   iOS 15.0
# 30     iPhone 13 Mini                                  iOS 15.0
# 31     iPhone 13 Pro                                   iOS 15.0
# 32  iPhone 13 Pro Max                                  iOS 15.0
#
#                                                 price
# 0                                          $499/$599*
# 1                                 $199/$299*$599/$699
# 2                                                $199
# 3                                                $599
# 4                       $199/$299/$399*$649/$749/$849
# 5                                                $649
# 6                                  $99/$199*$549/$649
# 7                       $199/$299/$399*$649/$749/$849
# 8   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 9   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 10  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 11  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 12                                          $399/$499
# 13  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 14  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 15                            $699/$849Plus:$799/$949
# 16                            $699/$849Plus:$799/$949
# 17                               $549/$699*$999/$1149
# 18                                     $749/$799/$899
# 19              $999/$1149/$1349Max:$1099/$1249/$1449
# 20              $999/$1149/$1349Max:$1099/$1249/$1449
# 21                                     $699/$749/$849
# 22             $999/$1149/$1349Max: $1099/$1249/$1449
# 23             $999/$1149/$1349Max: $1099/$1249/$1449
# 24                                     $399/$449/$549
# 25           $829/$879/$979**\nMini: $729/$779/$879**
# 26           $829/$879/$979**\nMini: $729/$779/$879**
# 27           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 28           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 29         $829/$929/$1129**\nMini: $729/$829/$1029**
# 30         $829/$929/$1129**\nMini: $729/$829/$1029**
# 31  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...
# 32  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...

# %% [markdown]
# ### Renaming OS to iOS (Version)

# %%
old_os = df.os
new_os = []
for os in old_os:
    try:
        new_os.append(os.split(' ')[0]+' '+os.split(' ')[1])
    except:
        print(os)
df.os = new_os
df
# Out:
#                 model          os  \
# 0              iPhone   iPhone OS
# 1           iPhone 3G   iPhone OS
# 2          iPhone 3GS   iPhone OS
# 3            iPhone 4     iOS 4.0
# 4           iPhone 4S     iOS 5.0
# 5            iPhone 5     iOS 6.0
# 6           iPhone 5C     iOS 7.0
# 7           iPhone 5S     iOS 7.0
# 8           iPhone 6      iOS 8.0
# 9       iPhone 6 Plus     iOS 8.0
# 10         iPhone 6S    iOS 9.0.1
# 11     iPhone 6S Plus   iOS 9.0.1
# 12    iPhone SE (1st)     iOS 9.3
# 13          iPhone 7   iOS 10.0.1
# 14      iPhone 7 Plus  iOS 10.0.1
# 15          iPhone 8     iOS 11.0
# 16      iPhone 8 Plus    iOS 11.0
# 17           iPhone X  iOS 11.0.1
# 18          iPhone XR    iOS 12.0
# 19         iPhone XS     iOS 12.0
# 20      iPhone XS Max    iOS 12.0
# 21          iPhone 11    iOS 13.0
# 22     iPhone 11 Pro     iOS 13.0
# 23  iPhone 11 Pro Max    iOS 13.0
# 24    iPhone SE (2nd)    iOS 13.4
# 25         iPhone 12     iOS 14.1
# 26     iPhone 12 Mini    iOS 14.1
# 27     iPhone 12 Pro     iOS 14.1
# 28  iPhone 12 Pro Max    iOS 14.1
# 29         iPhone 13     iOS 15.0
# 30     iPhone 13 Mini    iOS 15.0
# 31     iPhone 13 Pro     iOS 15.0
# 32  iPhone 13 Pro Max    iOS 15.0
#
#                                                 price
# 0                                          $499/$599*
# 1                                 $199/$299*$599/$699
# 2                                                $199
# 3                                                $599
# 4                       $199/$299/$399*$649/$749/$849
# 5                                                $649
# 6                                  $99/$199*$549/$649
# 7                       $199/$299/$399*$649/$749/$849
# 8   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 9   $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 10  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 11  $199/$299/$399*$649/$749/$849Plus:$299/$399/$4...
# 12                                          $399/$499
# 13  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 14  $199/$299/$399*$649/$749/$849Plus:$319/$419/$5...
# 15                            $699/$849Plus:$799/$949
# 16                            $699/$849Plus:$799/$949
# 17                               $549/$699*$999/$1149
# 18                                     $749/$799/$899
# 19              $999/$1149/$1349Max:$1099/$1249/$1449
# 20              $999/$1149/$1349Max:$1099/$1249/$1449
# 21                                     $699/$749/$849
# 22             $999/$1149/$1349Max: $1099/$1249/$1449
# 23             $999/$1149/$1349Max: $1099/$1249/$1449
# 24                                     $399/$449/$549
# 25           $829/$879/$979**\nMini: $729/$779/$879**
# 26           $829/$879/$979**\nMini: $729/$779/$879**
# 27           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 28           $999/$1099/$1299\nMax: $1099/$1199/$1399
# 29         $829/$929/$1129**\nMini: $729/$829/$1029**
# 30         $829/$929/$1129**\nMini: $729/$829/$1029**
# 31  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...
# 32  $999/$1099/$1299/$1499\nMax: $1099/$1199/$1399...

# %% [markdown]
# ### Separating special models' price (Mini, Max, Plus)

# %%
old_price = df.price
new_price = []
for price in old_price:
    try:
        new_price.append(price.split(':'))
    except:
        print(price)
df.price = new_price
df
# Out:
#                 model          os  \
# 0              iPhone   iPhone OS
# 1           iPhone 3G   iPhone OS
# 2          iPhone 3GS   iPhone OS
# 3            iPhone 4     iOS 4.0
# 4           iPhone 4S     iOS 5.0
# 5            iPhone 5     iOS 6.0
# 6           iPhone 5C     iOS 7.0
# 7           iPhone 5S     iOS 7.0
# 8           iPhone 6      iOS 8.0
# 9       iPhone 6 Plus     iOS 8.0
# 10         iPhone 6S    iOS 9.0.1
# 11     iPhone 6S Plus   iOS 9.0.1
# 12    iPhone SE (1st)     iOS 9.3
# 13          iPhone 7   iOS 10.0.1
# 14      iPhone 7 Plus  iOS 10.0.1
# 15          iPhone 8     iOS 11.0
# 16      iPhone 8 Plus    iOS 11.0
# 17           iPhone X  iOS 11.0.1
# 18          iPhone XR    iOS 12.0
# 19         iPhone XS     iOS 12.0
# 20      iPhone XS Max    iOS 12.0
# 21          iPhone 11    iOS 13.0
# 22     iPhone 11 Pro     iOS 13.0
# 23  iPhone 11 Pro Max    iOS 13.0
# 24    iPhone SE (2nd)    iOS 13.4
# 25         iPhone 12     iOS 14.1
# 26     iPhone 12 Mini    iOS 14.1
# 27     iPhone 12 Pro     iOS 14.1
# 28  iPhone 12 Pro Max    iOS 14.1
# 29         iPhone 13     iOS 15.0
# 30     iPhone 13 Mini    iOS 15.0
# 31     iPhone 13 Pro     iOS 15.0
# 32  iPhone 13 Pro Max    iOS 15.0
#
#                                                 price
# 0                                        [$499/$599*]
# 1                               [$199/$299*$599/$699]
# 2                                              [$199]
# 3                                              [$599]
# 4                     [$199/$299/$399*$649/$749/$849]
# 5                                              [$649]
# 6                                [$99/$199*$549/$649]
# 7                     [$199/$299/$399*$649/$749/$849]
# 8   [$199/$299/$399*$649/$749/$849Plus, $299/$399/...
# 9   [$199/$299/$399*$649/$749/$849Plus, $299/$399/...
# 10  [$199/$299/$399*$649/$749/$849Plus, $299/$399/...
# 11  [$199/$299/$399*$649/$749/$849Plus, $299/$399/...
# 12                                        [$399/$499]
# 13  [$199/$299/$399*$649/$749/$849Plus, $319/$419/...
# 14  [$199/$299/$399*$649/$749/$849Plus, $319/$419/...
# 15                         [$699/$849Plus, $799/$949]
# 16                         [$699/$849Plus, $799/$949]
# 17                             [$549/$699*$999/$1149]
# 18                                   [$749/$799/$899]
# 19           [$999/$1149/$1349Max, $1099/$1249/$1449]
# 20           [$999/$1149/$1349Max, $1099/$1249/$1449]
# 21                                   [$699/$749/$849]
# 22          [$999/$1149/$1349Max,  $1099/$1249/$1449]
# 23          [$999/$1149/$1349Max,  $1099/$1249/$1449]
# 24                                   [$399/$449/$549]
# 25        [$829/$879/$979**\nMini,  $729/$779/$879**]
# 26        [$829/$879/$979**\nMini,  $729/$779/$879**]
# 27        [$999/$1099/$1299\nMax,  $1099/$1199/$1399]
# 28        [$999/$1099/$1299\nMax,  $1099/$1199/$1399]
# 29      [$829/$929/$1129**\nMini,  $729/$829/$1029**]
# 30      [$829/$929/$1129**\nMini,  $729/$829/$1029**]
# 31  [$999/$1099/$1299/$1499\nMax,  $1099/$1199/$13...
# 32  [$999/$1099/$1299/$1499\nMax,  $1099/$1199/$13...

# %% [markdown]
# ### Assigning the correct starting prices to each model

# %%
new_price = []
for model,price in zip(df.model, df.price):
    if 'Max' in model or 'Mini' in model or 'Plus' in model:
        new_price.append(price[1])

    else:
        new_price.append(price[0])

df.price = new_price
df
# Out:
#                 model          os                              price
# 0              iPhone   iPhone OS                         $499/$599*
# 1           iPhone 3G   iPhone OS                $199/$299*$599/$699
# 2          iPhone 3GS   iPhone OS                               $199
# 3            iPhone 4     iOS 4.0                               $599
# 4           iPhone 4S     iOS 5.0      $199/$299/$399*$649/$749/$849
# 5            iPhone 5     iOS 6.0                               $649
# 6           iPhone 5C     iOS 7.0                 $99/$199*$549/$649
# 7           iPhone 5S     iOS 7.0      $199/$299/$399*$649/$749/$849
# 8           iPhone 6      iOS 8.0  $199/$299/$399*$649/$749/$849Plus
# 9       iPhone 6 Plus     iOS 8.0                $299/$399/$499*Plus
# 10         iPhone 6S    iOS 9.0.1  $199/$299/$399*$649/$749/$849Plus
# 11     iPhone 6S Plus   iOS 9.0.1                $299/$399/$499*Plus
# 12    iPhone SE (1st)     iOS 9.3                          $399/$499
# 13          iPhone 7   iOS 10.0.1  $199/$299/$399*$649/$749/$849Plus
# 14      iPhone 7 Plus  iOS 10.0.1                $319/$419/$519*Plus
# 15          iPhone 8     iOS 11.0                      $699/$849Plus
# 16      iPhone 8 Plus    iOS 11.0                          $799/$949
# 17           iPhone X  iOS 11.0.1               $549/$699*$999/$1149
# 18          iPhone XR    iOS 12.0                     $749/$799/$899
# 19         iPhone XS     iOS 12.0                $999/$1149/$1349Max
# 20      iPhone XS Max    iOS 12.0                  $1099/$1249/$1449
# 21          iPhone 11    iOS 13.0                     $699/$749/$849
# 22     iPhone 11 Pro     iOS 13.0                $999/$1149/$1349Max
# 23  iPhone 11 Pro Max    iOS 13.0                  $1099/$1249/$1449
# 24    iPhone SE (2nd)    iOS 13.4                     $399/$449/$549
# 25         iPhone 12     iOS 14.1             $829/$879/$979**\nMini
# 26     iPhone 12 Mini    iOS 14.1                   $729/$779/$879**
# 27     iPhone 12 Pro     iOS 14.1              $999/$1099/$1299\nMax
# 28  iPhone 12 Pro Max    iOS 14.1                  $1099/$1199/$1399
# 29         iPhone 13     iOS 15.0            $829/$929/$1129**\nMini
# 30     iPhone 13 Mini    iOS 15.0                  $729/$829/$1029**
# 31     iPhone 13 Pro     iOS 15.0        $999/$1099/$1299/$1499\nMax
# 32  iPhone 13 Pro Max    iOS 15.0            $1099/$1199/$1399/$1599

# %% [markdown]
# ### Correcting to price format to int

# %%
old_price = df.price
new_price = []
for price in old_price:
    new_price.append(int(price.replace('$','').split('/')[0]))
df.price = new_price
df
# Out:
#                 model          os  price
# 0              iPhone   iPhone OS    499
# 1           iPhone 3G   iPhone OS    199
# 2          iPhone 3GS   iPhone OS    199
# 3            iPhone 4     iOS 4.0    599
# 4           iPhone 4S     iOS 5.0    199
# 5            iPhone 5     iOS 6.0    649
# 6           iPhone 5C     iOS 7.0     99
# 7           iPhone 5S     iOS 7.0    199
# 8           iPhone 6      iOS 8.0    199
# 9       iPhone 6 Plus     iOS 8.0    299
# 10         iPhone 6S    iOS 9.0.1    199
# 11     iPhone 6S Plus   iOS 9.0.1    299
# 12    iPhone SE (1st)     iOS 9.3    399
# 13          iPhone 7   iOS 10.0.1    199
# 14      iPhone 7 Plus  iOS 10.0.1    319
# 15          iPhone 8     iOS 11.0    699
# 16      iPhone 8 Plus    iOS 11.0    799
# 17           iPhone X  iOS 11.0.1    549
# 18          iPhone XR    iOS 12.0    749
# 19         iPhone XS     iOS 12.0    999
# 20      iPhone XS Max    iOS 12.0   1099
# 21          iPhone 11    iOS 13.0    699
# 22     iPhone 11 Pro     iOS 13.0    999
# 23  iPhone 11 Pro Max    iOS 13.0   1099
# 24    iPhone SE (2nd)    iOS 13.4    399
# 25         iPhone 12     iOS 14.1    829
# 26     iPhone 12 Mini    iOS 14.1    729
# 27     iPhone 12 Pro     iOS 14.1    999
# 28  iPhone 12 Pro Max    iOS 14.1   1099
# 29         iPhone 13     iOS 15.0    829
# 30     iPhone 13 Mini    iOS 15.0    729
# 31     iPhone 13 Pro     iOS 15.0    999
# 32  iPhone 13 Pro Max    iOS 15.0   1099

# %% [markdown]
# ## Exporting to csv

# %%
df.to_csv('iphones.csv')
